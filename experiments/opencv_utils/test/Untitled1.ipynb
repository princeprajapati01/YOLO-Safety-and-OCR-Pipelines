# %%
import requests
import pandas as pd

# %%
url = "https://newsapi.org/v2/top-headlines?sources=techcrunch&apiKey=fc27e5cbadad4e74b1b5cd0c8111eb37"

response = requests.get(url)
response.status_code
# Out:
# 200

# %%
data = response.json()

# %%
data
# Out:
# {'status': 'ok',
#  'totalResults': 10,
#  'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Lauren Forristal',
#    'title': "Bye-bye bots: Altera's game-playing AI agents get backing from Eric Schmidt | TechCrunch",
#    'description': 'Autonomous, AI-based players are coming to a gaming experience near you, and a new startup, Altera, is joining the fray to build this new guard of AI Research company Altera raised $9 million to build AI agents that can play video games alongside other player…',
#    'url': 'https://techcrunch.com/2024/05/08/bye-bye-bots-alteras-game-playing-ai-agents-get-backing-from-eric-schmidt/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2024/05/Minecraft-keyart.jpg?resize=1200,720',
#    'publishedAt': '2024-05-08T15:14:57Z',
# ...

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   status  totalResults                                           articles
# 0     ok            10  {'source': {'id': 'techcrunch', 'name': 'TechC...
# 1     ok            10  {'source': {'id': 'techcrunch', 'name': 'TechC...
# 2     ok            10  {'source': {'id': 'techcrunch', 'name': 'TechC...
# 3     ok            10  {'source': {'id': 'techcrunch', 'name': 'TechC...
# 4     ok            10  {'source': {'id': 'techcrunch', 'name': 'TechC...
# 5     ok            10  {'source': {'id': 'techcrunch', 'name': 'TechC...
# 6     ok            10  {'source': {'id': 'techcrunch', 'name': 'TechC...
# 7     ok            10  {'source': {'id': 'techcrunch', 'name': 'TechC...
# 8     ok            10  {'source': {'id': 'techcrunch', 'name': 'TechC...
# 9     ok            10  {'source': {'id': 'techcrunch', 'name': 'TechC...

# %%
df.to_csv("new.csv",index=False)

# %%
df['articles']
# Out:
# 0    {'source': {'id': 'techcrunch', 'name': 'TechC...
# 1    {'source': {'id': 'techcrunch', 'name': 'TechC...
# 2    {'source': {'id': 'techcrunch', 'name': 'TechC...
# 3    {'source': {'id': 'techcrunch', 'name': 'TechC...
# 4    {'source': {'id': 'techcrunch', 'name': 'TechC...
# 5    {'source': {'id': 'techcrunch', 'name': 'TechC...
# 6    {'source': {'id': 'techcrunch', 'name': 'TechC...
# 7    {'source': {'id': 'techcrunch', 'name': 'TechC...
# 8    {'source': {'id': 'techcrunch', 'name': 'TechC...
# 9    {'source': {'id': 'techcrunch', 'name': 'TechC...
# Name: articles, dtype: object

# %%
import requests
import pandas as pd
url = 'https://newsapi.org/v2/everything?q=bitcoin&apiKey=fc27e5cbadad4e74b1b5cd0c8111eb37'

# %%
response = requests.get(url)

# %%
data = response.json()
data
# Out:
# {'status': 'ok',
#  'totalResults': 7218,
#  'articles': [{'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Torpey',
#    'title': 'Popular Musician Loses Life Savings Through Malicious Crypto Wallet in Apple’s App Store',
#    'description': 'The theft apparently combined a counterfeit app with a critical mistake by the musician.',
#    'url': 'https://gizmodo.com/popular-musician-loses-life-savings-through-malicious-crypto-wallet-in-apples-app-store-2000745902',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2026/04/g-love-crypto-theft-1200x675.jpg',
#    'publishedAt': '2026-04-13T21:25:17Z',
#    'content': 'Musician G. Love lost his life savings after downloading a fake Ledger Live app from Apple’s Mac App Store, according to a post made to his X account. Noted blockchain investigator ZachXBT traced the… [+4424 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#    status  totalResults                                           articles
# 0      ok          7218  {'source': {'id': None, 'name': 'Gizmodo.com'}...
# 1      ok          7218  {'source': {'id': None, 'name': 'BBC News'}, '...
# 2      ok          7218  {'source': {'id': None, 'name': 'Gizmodo.com'}...
# 3      ok          7218  {'source': {'id': None, 'name': 'Gizmodo.com'}...
# 4      ok          7218  {'source': {'id': None, 'name': 'Gizmodo.com'}...
# ..    ...           ...                                                ...
# 91     ok          7218  {'source': {'id': None, 'name': 'Yahoo Enterta...
# 92     ok          7218  {'source': {'id': None, 'name': 'Yahoo Enterta...
# 93     ok          7218  {'source': {'id': None, 'name': 'Yahoo Enterta...
# 94     ok          7218  {'source': {'id': None, 'name': 'Yahoo Enterta...
# 95     ok          7218  {'source': {'id': None, 'name': 'Yahoo Enterta...
#
# [96 rows x 3 columns]

# %%
df.to_csv('p1.csv',index=False)
